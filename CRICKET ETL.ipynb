# %% [markdown]
# ## T20 WORLD CUP CRICKET DATA PROCESSING ##

# %%
import pandas as pd
import json

# %%
import os
print(os.getcwd())

print(os.listdir())
# Out:
# C:\Users\TIZAOUI\CRICKET ANALYSIS
# ['.ipynb_checkpoints', 'CRICKET.ipynb', 't20_wc_batting_summary.json', 't20_wc_bowling_summary.json', 't20_wc_match_results.json', 't20_wc_player_info.json']

# %% [markdown]
# ### Process Match Results

# %%
with open("t20_wc_match_results.json") as f:
    data = json.load(f)
data
len(data) #has 1 element if you look in the jason file ther is only one []
data[0]['matchSummary']
# Out:
# 1

# %%
df_match= pd.DataFrame(data[0]['matchSummary'])
df_match.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#      scorecard
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %%
df_match.shape
# Out:
# (45, 7)

# %%
#rename column in DF
df_match.rename({'scorecard' : 'match_id'}, axis=1, inplace=True)
df_match.head()
# Out:
#          team1        team2       winner     margin   ground     matchDate  \
# 0      Namibia    Sri Lanka      Namibia    55 runs  Geelong  Oct 16, 2022
# 1  Netherlands       U.A.E.  Netherlands  3 wickets  Geelong  Oct 16, 2022
# 2     Scotland  West Indies     Scotland    42 runs   Hobart  Oct 17, 2022
# 3      Ireland     Zimbabwe     Zimbabwe    31 runs   Hobart  Oct 17, 2022
# 4      Namibia  Netherlands  Netherlands  5 wickets  Geelong  Oct 18, 2022
#
#       match_id
# 0  T20I # 1823
# 1  T20I # 1825
# 2  T20I # 1826
# 3  T20I # 1828
# 4  T20I # 1830

# %% [markdown]
# ### Process Batting Summary

# %%
with open("t20_wc_batting_summary.json") as f:
    data = json.load(f)
len(data)
data
# Out:
# 45

# %%
# Afficher tous les éléments un par un
for i, rec in enumerate(data, start=1):
    print(f"--- Élément {i} ---")
    print(rec)
    print("\n")

# %%
all_records=[] #cree une liste vide pour mettre la liste des dictionnaires contenus dans chaque élement : "battingSummary". dedans un format 
#compris ar pandas afin de pouvoir converir d'un format imbriqué json a un format dictionnaire seule ligne 

for rec in data : 
    all_records.extend(rec["battingSummary"])   
df_batting= pd.DataFrame(all_records)
df_batting.head(20)

 #rec["battingSummary"] est une liste de dictionnaires originale en json
#all_records.extend(rec["battingSummary"])  :ajoute tous les dictionnaires de cette liste à all_records grace a extend 
#Après la boucle, all_records est une seule grande liste contenant tous les dictionnaires de tous les matchs.
# Out:
#                     match teamInnings  battingPos                 batsmanName  \
# 0    Namibia Vs Sri Lanka     Namibia           1          Michael van Lingen
# 1    Namibia Vs Sri Lanka     Namibia           2               Divan la Cock
# 2    Namibia Vs Sri Lanka     Namibia           3      Jan Nicol Loftie-Eaton
# 3    Namibia Vs Sri Lanka     Namibia           4               Stephan Baard
# 4    Namibia Vs Sri Lanka     Namibia           5          Gerhard Erasmus(c)
# 5    Namibia Vs Sri Lanka     Namibia           6                Jan Frylinck
# 6    Namibia Vs Sri Lanka     Namibia           7                 David Wiese
# 7    Namibia Vs Sri Lanka     Namibia           8                     JJ Smit
# 8    Namibia Vs Sri Lanka   Sri Lanka           1             Pathum Nissanka
# 9    Namibia Vs Sri Lanka   Sri Lanka           2             Kusal Mendisâ€
# 10   Namibia Vs Sri Lanka   Sri Lanka           3         Dhananjaya de Silva
# ...

# %%
#create a new column "out/not out" based on whether "dismissal" is empty or not.
df_batting["out/not out"] =df_batting["dismissal"].apply(
   lambda x: "out" if len(x) > 0 else "not out")

df_batting["out/not out"] = np.where(df_batting["dismissal"] == "", "not out", "out") ~#2eme facon

df_batting.head(11)

# %%
#drop column dismissal
df_batting.drop(columns=["dismissal"], inplace = True)

# %%
df_batting.head(10)
# Out:
#                   match teamInnings  battingPos             batsmanName runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
# 5  Namibia Vs Sri Lanka     Namibia           6            Jan Frylinck   44
# 6  Namibia Vs Sri Lanka     Namibia           7             David Wiese    0
# 7  Namibia Vs Sri Lanka     Namibia           8                 JJ Smit   31
# 8  Namibia Vs Sri Lanka   Sri Lanka           1         Pathum Nissanka    9
# 9  Namibia Vs Sri Lanka   Sri Lanka           2         Kusal Mendisâ€     6
#
#   balls 4s 6s      SR out/not out
# 0     6  0  0   50.00         out
# 1     9  1  0  100.00         out
# ...

# %%
import re
# show rows with non-ASCII characters in 'batsmanName'
df_batting[df_batting['batsmanName'].str.contains(r'[^\x00-\x7F]')]
# Out:
#                        match  teamInnings  battingPos            batsmanName  \
# 9       Namibia Vs Sri Lanka    Sri Lanka           2        Kusal Mendisâ€
# 22     U.A.E. Vs Netherlands       U.A.E.           4     Vriitya Aravindâ€
# 34     U.A.E. Vs Netherlands  Netherlands           6    Scott Edwards(c)â€
# 40   Scotland Vs West Indies     Scotland           3       Matthew Crossâ€
# 48   Scotland Vs West Indies  West Indies           4  Nicholas Pooran(c)â€
# ..                       ...          ...         ...                    ...
# 668  New Zealand Vs Pakistan     Pakistan           1     Mohammad Rizwanâ€
# 678         India Vs England        India           6        Rishabh Pantâ€
# 680         India Vs England      England           1      Jos Buttler(c)â€
# 682      Pakistan Vs England     Pakistan           1     Mohammad Rizwanâ€
# 692      Pakistan Vs England      England           1      Jos Buttler(c)â€
#
#     runs balls 4s 6s      SR out/not out
# ...

# %%
df_batting['batsmanName']=df_batting['batsmanName'].apply( lambda x : x.replace('â€', ''))
df_batting['batsmanName']=df_batting['batsmanName'].apply( lambda x : x.replace('\xa0', ''))
df_batting.head(15)
# Out:
#                    match teamInnings  battingPos                 batsmanName  \
# 0   Namibia Vs Sri Lanka     Namibia           1          Michael van Lingen
# 1   Namibia Vs Sri Lanka     Namibia           2               Divan la Cock
# 2   Namibia Vs Sri Lanka     Namibia           3      Jan Nicol Loftie-Eaton
# 3   Namibia Vs Sri Lanka     Namibia           4               Stephan Baard
# 4   Namibia Vs Sri Lanka     Namibia           5          Gerhard Erasmus(c)
# 5   Namibia Vs Sri Lanka     Namibia           6                Jan Frylinck
# 6   Namibia Vs Sri Lanka     Namibia           7                 David Wiese
# 7   Namibia Vs Sri Lanka     Namibia           8                     JJ Smit
# 8   Namibia Vs Sri Lanka   Sri Lanka           1             Pathum Nissanka
# 9   Namibia Vs Sri Lanka   Sri Lanka           2                Kusal Mendis
# 10  Namibia Vs Sri Lanka   Sri Lanka           3         Dhananjaya de Silva
# ...

# %%
#create column id in the df_batting based on the columns match , team1	and team2 
match_ids_dict = {}
for index, row in df_match.iterrows():
    key1 = row['team1'] + ' Vs ' + row['team2']
    key2 = row['team2'] + ' Vs ' + row['team1']  # reversed
    match_ids_dict[key1] = row["match_id"]
    match_ids_dict[key2] = row["match_id"]

#ca cest pour les colonnes par Namibia Vs Sri Lank et  Sri Lank Namibia Vs
#drop column dismissal

# %%
df_batting["match_id"]=df_batting['match'].map(match_ids_dict)
df_batting.head()
# Out:
#                   match teamInnings  battingPos             batsmanName runs  \
# 0  Namibia Vs Sri Lanka     Namibia           1      Michael van Lingen    3
# 1  Namibia Vs Sri Lanka     Namibia           2           Divan la Cock    9
# 2  Namibia Vs Sri Lanka     Namibia           3  Jan Nicol Loftie-Eaton   20
# 3  Namibia Vs Sri Lanka     Namibia           4           Stephan Baard   26
# 4  Namibia Vs Sri Lanka     Namibia           5      Gerhard Erasmus(c)   20
#
#   balls 4s 6s      SR out/not out     match_id
# 0     6  0  0   50.00         out  T20I # 1823
# 1     9  1  0  100.00         out  T20I # 1823
# 2    12  1  2  166.66         out  T20I # 1823
# 3    24  2  0  108.33         out  T20I # 1823
# 4    24  0  0   83.33         out  T20I # 1823

# %% [markdown]
# ### Process Bowling Summary

# %%
with open ("t20_wc_bowling_summary.json") as f : 
    data=json.load(f)
all_records=[]
for rec in data :
    all_records.extend(rec["bowlingSummary"])
all_records[:3]
# Out:
# [{'match': 'Namibia Vs Sri Lanka',
#   'bowlingTeam': 'Sri Lanka',
#   'bowlerName': 'Maheesh Theekshana',
#   'overs': '4',
#   'maiden': '0',
#   'runs': '23',
#   'wickets': '1',
#   'economy': '5.75',
#   '0s': '7',
#   '4s': '0',
#   '6s': '0',
#   'wides': '2',
#   'noBalls': '0'},
#  {'match': 'Namibia Vs Sri Lanka',
#   'bowlingTeam': 'Sri Lanka',
#   'bowlerName': 'Dushmantha Chameera',
#   'overs': '4',
#   'maiden': '0',
#   'runs': '39',
#   'wickets': '1',
#   'economy': '9.75',
#   '0s': '6',
#   '4s': '3',
#   '6s': '1',
#   'wides': '2',
#   'noBalls': '0'},
#  {'match': 'Namibia Vs Sri Lanka',
#   'bowlingTeam': 'Sri Lanka',
#   'bowlerName': 'Pramod Madushan',
#   'overs': '4',
#   'maiden': '0',
#   'runs': '37',
#   'wickets': '2',
#   'economy': '9.25',
#   '0s': '6',
#   '4s': '3',
#   '6s': '1',
#   'wides': '0',
#   'noBalls': '0'}]

# %%
df_bowling=pd.DataFrame(all_records)
print(df_bowling.shape)
df_bowling.head()
# Out:
# (500, 13)
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls
# 0   23       1    5.75  7  0  0     2       0
# 1   39       1    9.75  6  3  1     2       0
# 2   37       2    9.25  6  3  1     0       0
# 3   36       1    9.00  7  3  1     1       0
# 4   27       1    6.75  8  1  1     0       0

# %%
df_bowling['match_id']=df_bowling['match'].map(match_ids_dict)
df_bowling.head()
# Out:
#                   match bowlingTeam                  bowlerName overs maiden  \
# 0  Namibia Vs Sri Lanka   Sri Lanka          Maheesh Theekshana     4      0
# 1  Namibia Vs Sri Lanka   Sri Lanka         Dushmantha Chameera     4      0
# 2  Namibia Vs Sri Lanka   Sri Lanka             Pramod Madushan     4      0
# 3  Namibia Vs Sri Lanka   Sri Lanka         Chamika Karunaratne     4      0
# 4  Namibia Vs Sri Lanka   Sri Lanka  Wanindu Hasaranga de Silva     4      0
#
#   runs wickets economy 0s 4s 6s wides noBalls     match_id
# 0   23       1    5.75  7  0  0     2       0  T20I # 1823
# 1   39       1    9.75  6  3  1     2       0  T20I # 1823
# 2   37       2    9.25  6  3  1     0       0  T20I # 1823
# 3   36       1    9.00  7  3  1     1       0  T20I # 1823
# 4   27       1    6.75  8  1  1     0       0  T20I # 1823

# %% [markdown]
# ### Process players infos

# %%
with open ("t20_wc_player_info.json") as f:
    data= json.load(f)
data[:4]
# Out:
# [{'name': 'Michael van Lingen',
#   'team': 'Namibia',
#   'battingStyle': 'Left hand Bat',
#   'bowlingStyle': 'Left arm Medium',
#   'playingRole': 'Bowling Allrounder',
#   'description': ''},
#  {'name': 'Divan la Cock',
#   'team': 'Namibia',
#   'battingStyle': 'Right hand Bat',
#   'bowlingStyle': 'Legbreak',
#   'playingRole': 'Opening Batter',
#   'description': ''},
#  {'name': 'Jan Nicol Loftie-Eaton',
#   'team': 'Namibia',
#   'battingStyle': 'Left hand Bat',
#   'bowlingStyle': 'Right arm Medium, Legbreak',
#   'playingRole': 'Batter',
#   'description': ''},
#  {'name': 'Stephan Baard',
#   'team': 'Namibia',
#   'battingStyle': 'Right hand Bat',
#   'bowlingStyle': 'Right arm Medium fast',
#   'playingRole': 'Batter',
#   'description': ''}]

# %%
df_players = pd.DataFrame(data)
df_players
# Out:
#                        name          team    battingStyle  \
# 0        Michael van Lingen       Namibia   Left hand Bat
# 1             Divan la Cock       Namibia  Right hand Bat
# 2    Jan Nicol Loftie-Eaton       Namibia   Left hand Bat
# 3             Stephan Baard       Namibia  Right hand Bat
# 4        Gerhard Erasmus(c)       Namibia  Right hand Bat
# ..                      ...           ...             ...
# 214          Tabraiz Shamsi  South Africa  Right hand Bat
# 215               Phil Salt       England  Right hand Bat
# 216            Chris Jordan       England  Right hand Bat
# 217    Regis Chakabva(c)â€       Zimbabwe  Right hand Bat
# 218      Mehidy Hasan Miraz    Bangladesh  Right hand Bat
#
#                    bowlingStyle          playingRole  \
# 0               Left arm Medium   Bowling Allrounder
# 1                      Legbreak       Opening Batter
# 2    Right arm Medium, Legbreak               Batter
# ...

# %% [markdown]
# #### Nettoyage

# %%
df_players['name']=df_players['name'].apply(lambda x : x.replace('â€', ''))
df_players['name']=df_players['name'].apply(lambda x :x.replace('†', ''))
df_players['name'] =df_players['name'].apply(lambda x: x.replace('\xa0', ''))
df_players.head(10)
# Out:
#                      name       team    battingStyle  \
# 0      Michael van Lingen    Namibia   Left hand Bat
# 1           Divan la Cock    Namibia  Right hand Bat
# 2  Jan Nicol Loftie-Eaton    Namibia   Left hand Bat
# 3           Stephan Baard    Namibia  Right hand Bat
# 4      Gerhard Erasmus(c)    Namibia  Right hand Bat
# 5            Jan Frylinck    Namibia   Left hand Bat
# 6             David Wiese    Namibia  Right hand Bat
# 7                 JJ Smit    Namibia  Right hand Bat
# 8         Pathum Nissanka  Sri Lanka  Right hand Bat
# 9            Kusal Mendis  Sri Lanka  Right hand Bat
#
#                  bowlingStyle          playingRole  \
# 0             Left arm Medium   Bowling Allrounder
# 1                    Legbreak       Opening Batter
# 2  Right arm Medium, Legbreak               Batter
# 3       Right arm Medium fast               Batter
# 4          Right arm Offbreak           Allrounder
# 5        Left arm Fast medium           Allrounder
# ...

# %%
df_players[df_players['team']=='Sri Lanka']
# Out:
#                            name       team    battingStyle  \
# 8               Pathum Nissanka  Sri Lanka  Right hand Bat
# 9                  Kusal Mendis  Sri Lanka  Right hand Bat
# 10          Dhananjaya de Silva  Sri Lanka  Right hand Bat
# 11         Danushka Gunathilaka  Sri Lanka   Left hand Bat
# 12            Bhanuka Rajapaksa  Sri Lanka   Left hand Bat
# 13             Dasun Shanaka(c)  Sri Lanka  Right hand Bat
# 14   Wanindu Hasaranga de Silva  Sri Lanka  Right hand Bat
# 15          Chamika Karunaratne  Sri Lanka  Right hand Bat
# 16              Pramod Madushan  Sri Lanka  Right hand Bat
# 17          Dushmantha Chameera  Sri Lanka  Right hand Bat
# 18           Maheesh Theekshana  Sri Lanka  Right hand Bat
# 22             Charith Asalanka  Sri Lanka   Left hand Bat
# 32              Binura Fernando  Sri Lanka  Right hand Bat
# 33                Lahiru Kumara  Sri Lanka   Left hand Bat
# 34                Dasun Shanaka  Sri Lanka  Right hand Bat
# ...

# %% [markdown]
# ## Data_cleaned exportation ##

# %%
df_match.to_excel('dim_match_summary3.xlsx', index=False)

# %%
#export "df_batting_cleaned.csv", index=False)
df_batting.to_csv('fact_bating_summary.csv' , index=False)

# %%
df_bowling.to_csv('fact_bowling_summary.csv' , index=False)

# %%
df_players.to_excel('dim_players.xlsx', index=False)

# %%
import pandas as pd

#Read the CSV file
df = pd.read_csv("dim_players (1).csv")

#Export it to Excel
df.to_excel("dim_players (1).xlsx", index=False)
